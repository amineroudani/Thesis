# %%
from ThesisFunctions import *

# %%
# Define the range of noise levels to analyze.
#noise_levels = [0.1, 0.2, 0.5, 0.6, 0.7, 0.8, 1, 1.2, 1.5, 2, 3, 4, 10, 20, 30, 40, 70, 100, 200, 300, 400, 500]
noise_levels = [0.1]
# Set the number of data points for each generated dataset.
num_datapoints = 6

# Initialize a list to store the results for each noise level.
results_list = []
num_minimas = 1
data = 0

for level in noise_levels:
    num_minimas_list = []  # List to store the number of minima found in each iteration for current noise level.
    print("5 done")
    if num_minimas == 0:
        break
    for _ in range(100):  # Perform the analysis 10 times to average out the stochastic effects of noise.
        # Generate synthetic data.
        data = data_gen(num_datapoints, level, 1, 1)
        x_i = np.array(data['Data'].values)
        t_i = np.array(data['Time'].values)
        plt.scatter(t_i, x_i)
        # Compute the Groebner basis.
        B = groeb(x_i, t_i)
                        
        # Identify positive real roots.
        positive_roots_b = roots_symbolic(B[1])
        
        # Find corresponding (x0, alpha) pairs.
        params = find_x0_alpha_pairs(B, positive_roots_b)
        
        # Evaluate the Hessian at each (x0, alpha) pair.
        maxima_checks = evaluate_hessian_at_extremas(params, x_i, t_i)

        # Count the number of minima.
        num_minimas = sum(1 for _, is_true in maxima_checks if is_true)
        if num_minimas == 0:
            print(data)
            break
            #num_minimas_list.append(1)
        
        
        num_minimas_list.append(num_minimas)
        
            

    # Calculate average and standard deviation of minima count for the current noise level.
    max_num_minimas = np.max(num_minimas_list)
    avg_num_minimas = np.mean(num_minimas_list)
    std_num_minimas = np.std(num_minimas_list)
    
    #print(f'Noise Level={level}: Mean of positive roots = {avg_num_minimas}, Std Dev = {std_num_minimas}, Max = {max_num_minimas}')

    # Append the results for the current noise level to the results list.
    results_list.append({
        'Noise_Level': level,
        'Average_Minimas': avg_num_minimas,
        'STD_Minimas': std_num_minimas,
        'Max_Minimas': max_num_minimas,
    })

# Convert the results list into a DataFrame.
results_df = pd.DataFrame(results_list)

# Display the DataFrame.
print(results_df)
# Out:
# 5 done
#    Noise_Level  Average_Minimas  STD_Minimas  Max_Minimas
# 0          0.1              1.0          0.0            1

# %%
# Define the range of noise levels to analyze.
#noise_levels = [0.1, 0.2, 0.5, 0.6, 0.7, 0.8, 1, 1.2, 1.5, 2, 3, 4, 10, 20, 30, 40, 70, 100, 200, 300, 400, 500]
noise_levels = [0.2]
# Set the number of data points for each generated dataset.
num_datapoints = 6

# Initialize a list to store the results for each noise level.
results_list = []
num_minimas = 1
data = 0

for level in noise_levels:
    num_minimas_list = []  # List to store the number of minima found in each iteration for current noise level.
    print("5 done")
    if num_minimas == 0:
        break
    for _ in range(100):  # Perform the analysis 10 times to average out the stochastic effects of noise.
        # Generate synthetic data.
        data = data_gen(num_datapoints, level, 1, 1)
        x_i = np.array(data['Data'].values)
        t_i = np.array(data['Time'].values)
        plt.scatter(t_i, x_i)
        # Compute the Groebner basis.
        B = groeb(x_i, t_i)
                        
        # Identify positive real roots.
        positive_roots_b = roots_symbolic(B[1])
        
        # Find corresponding (x0, alpha) pairs.
        params = find_x0_alpha_pairs(B, positive_roots_b)
        
        # Evaluate the Hessian at each (x0, alpha) pair.
        maxima_checks = evaluate_hessian_at_extremas(params, x_i, t_i)

        # Count the number of minima.
        num_minimas = sum(1 for _, is_true in maxima_checks if is_true)
        if num_minimas == 0:
            print(data)
            break
            #num_minimas_list.append(1)
        
        
        num_minimas_list.append(num_minimas)
        
            

    # Calculate average and standard deviation of minima count for the current noise level.
    max_num_minimas = np.max(num_minimas_list)
    avg_num_minimas = np.mean(num_minimas_list)
    std_num_minimas = np.std(num_minimas_list)
    
    #print(f'Noise Level={level}: Mean of positive roots = {avg_num_minimas}, Std Dev = {std_num_minimas}, Max = {max_num_minimas}')

    # Append the results for the current noise level to the results list.
    results_list.append({
        'Noise_Level': level,
        'Average_Minimas': avg_num_minimas,
        'STD_Minimas': std_num_minimas,
        'Max_Minimas': max_num_minimas,
    })

# Convert the results list into a DataFrame.
results_df = pd.DataFrame(results_list)

# Display the DataFrame.
print(results_df)
# Out:
# 5 done
#    Time      Data
# 0     0    89/100
# 1     1     27/20
# 2     2    149/25
# 3     3     134/5
# 4     4  2753/100
# 5     5     691/4
#    Noise_Level  Average_Minimas  STD_Minimas  Max_Minimas
# 0          0.2              1.0          0.0            1

# %%
data
x_i = np.array(data['Data'].values)
t_i = np.array(data['Time'].values)

# %%
plt.scatter(t_i, x_i)

# %%
# Compute the Groebner basis.
B = groeb(x_i, t_i)
print(B[1])
# Out:
# b**18 - 198252616*b**17/47558075 + 1092749*b**16/9511615 - 566594798*b**15/47558075 - 21493647*b**14/9511615 - 975615108*b**13/47558075 - 9708489*b**12/1902323 - 1390413566*b**11/47558075 - 15228756*b**10/1902323 - 1805793984*b**9/47558075 - 103771548*b**8/9511615 - 430668178*b**7/47558075 - 26771551*b**6/9511615 - 46805452*b**5/47558075 - 3562997*b**4/9511615 - 3121858*b**3/47558075 - 37797*b**2/1902323 - 116392*b/47558075 - 2403/9511615

# %%
# Identify positive real roots.
positive_roots_b = roots_symbolic(B[1])
positive_roots_b
# Out:
# [4.74121473067341]

# %%
params = find_x0_alpha_pairs(B, positive_roots_b)
#params = [(0, params[0][1])]
params
# Out:
# [(0.0719070434570313, 1.5562933751688188)]

# %%
# Evaluate the Hessian at each (x0, alpha) pair.
maxima_checks = evaluate_hessian_at_extremas(params, x_i, t_i)
maxima_checks
# Out:
# Matrix([[12014039.8139624, 905000.798858480], [905000.798858480, 68056.5972140932]])
# [((0.0719070434570313, 1.5562933751688188), False)]

# %%
# Define the range for alpha and x0
alpha_range = np.linspace(0.7, 5, 100)  # Adjust the range as needed
x0_range = np.linspace(-1, 2, 100)  # Adjust the range as needed


# Generate a meshgrid for x0 and alpha ranges
X0, Alpha = np.meshgrid(x0_range, alpha_range)


# Initialize an array to store SSE values
SSE_values = np.zeros(X0.shape)


# Compute SSE for each combination of x0 and alpha
for i in range(len(alpha_range)):
    for j in range(len(x0_range)):
        params_ = (X0[i, j], Alpha[i, j])
        SSE_values[i, j] = sse(params_, data)

        
# Creating the plot
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')


# Surface plot with log scale (since data is exponential)
surf = ax.plot_surface(X0, Alpha, np.log(np.log(SSE_values)), cmap='viridis', edgecolor='none')


# Labels and title
ax.set_xlabel('x0')
ax.set_ylabel('Alpha')
ax.set_zlabel('log SSE')
ax.set_title('SSE as a Function of x0 and Alpha')


# Colorbar to show the SSE scale better/clearer
fig.colorbar(surf, shrink=0.5, aspect=5)

ax.view_init(elev=20, azim=60)

# Show the plot with the adjusted view
plt.show()

# %%
#Analyzing a case with 2 datapoints, but 0 minima...
t_i = [0, 1]
x_i = [sp.Rational(-3/5), sp.Rational(11/5)]
data = pd.DataFrame({'Time': t_i, 'Data': x_i})

#Matrix([[2.14876033057851, -22/5], [-22/5, 0]])

# %%
plt.scatter(t_i, x_i)


def model_func(t, A, alpha):
    return A * np.exp(alpha * t)
    
t_values_for_plot = np.linspace(min(t_i), max(t_i), 100)
fitted_y_values = model_func(t_values_for_plot, 0.5, 1)
plt.plot(t_values_for_plot, fitted_y_values, color='blue', label='Fitted Curve')  # The fitted curve

# %%
B = groeb(x_i, t_i)
B
# Out:
# GroebnerBasis([-72344331047879694937860229707095766381330266325*b/474988032132543517376390223048474350148590239744 + x0 + 157842176831737497641996064378315968350761944875/3799904257060348139011121784387794801188721917952, b**2 + 363460780097437999569545317559831*b/107091122707280824522185099255480 - 1], x0, b, domain='QQ', order='lex')

# %%
positive_roots_b = roots_symbolic(B[1])
positive_roots_b
# Out:
# [0.272727272727273]

# %%
params = find_x0_alpha_pairs(B, positive_roots_b)
#params2 = params
#params = [(0, params2[0][1])]
params
# Out:
# [(0.0, -1.2992829841302609)]

# %%
x0, b = sp.symbols('x0 b')

x0_1 = sp.solve(B[0].subs(b, positive_roots_b[0]), x0)[0]
alpha_1 = sp.log(positive_roots_b[0])

x0_1, alpha_1
# Out:
# (0, -1.29928298413026)

# %%
def poly(b):
    return B[1]

# %%
print(poly(b))
# Out:
# b**2 + 363460780097437999569545317559831*b/107091122707280824522185099255480 - 1

# %%
x = B[1].subs(b, 0.27)
print(x)
# Out:
# -0.0107363636363634

# %%
maxima_checks = evaluate_hessian_at_extremas(params, x_i, t_i)
maxima_checks
# Out:
# [((0.0, -1.2992829841302609), True)]

# %%
# Define the range for alpha and x0
alpha_range = np.linspace(-100, 10, 100)  # Adjust the range as needed
x0_range = np.linspace(-50, 50, 200)  # Adjust the range as needed


# Generate a meshgrid for x0 and alpha ranges
X0, Alpha = np.meshgrid(x0_range, alpha_range)


# Initialize an array to store SSE values
SSE_values = np.zeros(X0.shape)


# Compute SSE for each combination of x0 and alpha
for i in range(len(alpha_range)):
    for j in range(len(x0_range)):
        params_ = (X0[i, j], Alpha[i, j])
        SSE_values[i, j] = sse(params_, data)

        
# Creating the plot
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')


# Surface plot with log scale (since data is exponential)
surf = ax.plot_surface(X0, Alpha, np.log(SSE_values), cmap='viridis', edgecolor='none')


# Labels and title
ax.set_xlabel('x0')
ax.set_ylabel('Alpha')
ax.set_zlabel('log SSE')
ax.set_title('SSE as a Function of x0 and Alpha')


# Colorbar to show the SSE scale better/clearer
fig.colorbar(surf, shrink=0.5, aspect=5)

#ax.view_init(elev=-10, azim=10)

# Show the plot with the adjusted view
plt.show()
